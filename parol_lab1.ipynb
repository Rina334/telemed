# %%
import hashlib
import string

# %%
def generate(alphabet, max_len):     
    if max_len <= 1: return     
    for c in alphabet:         
        yield c     
    for c in alphabet:         
        for next in generate(alphabet, max_len-1):             
            yield c + next 

gen = generate('oka', 2) 

for item in gen:     
    print(item) 

def generate(alphabet, max_len):     
    if max_len <= 1: return     
    for c in alphabet:         
        yield c     
    for c in alphabet:         
        for next in generate(alphabet, max_len-1):             
            yield c + next 

gen = generate('OKA', 2) 

for item2 in gen:     
    print(item2) 

def generate(alphabet, max_len):     
    if max_len <= 1: return     
    for c in alphabet:         
        yield c     
    for c in alphabet:         
        for next in generate(alphabet, max_len-1):             
            yield c + next 

gen = generate('123', 2) 

for item3 in gen:     
    print(item3)
# Out:
# o
# k
# a
# O
# K
# A
# 1
# 2
# 3

# %%
#password='oka'
res=hashlib.md5(item.encode())
print(res.hexdigest())

#password='OKA'
res=hashlib.md5(item2.encode())
print(res.hexdigest())

#password='123'
res=hashlib.md5(item3.encode())
print(res.hexdigest())
# Out:
# 0cc175b9c0f1b6a831c399e269772661
# 7fc56270e7a70fa81a5935b72eacbe29
# eccbc87e4b5ce2fe28308fd9f2a7baf3

# %%
password='1'
res=hashlib.md5(password.encode())
print(res.hexdigest())

password2='2'
res=hashlib.md5(password2.encode())
print(res.hexdigest())

password3='3'
res=hashlib.md5(password3.encode())
print(res.hexdigest())
# Out:
# c4ca4238a0b923820dcc509a6f75849b
# c81e728d9d4c2f636f067f89cc14862c
# eccbc87e4b5ce2fe28308fd9f2a7baf3

# %%
password='o'
res=hashlib.md5(password.encode())
print(res.hexdigest())

password2='k'
res=hashlib.md5(password2.encode())
print(res.hexdigest())

password3='a'
res=hashlib.md5(password3.encode())
print(res.hexdigest())
# Out:
# d95679752134a2d9eb61dbd7b91c4bcc
# 8ce4b16b22b58894aa86c421e8759df3
# 0cc175b9c0f1b6a831c399e269772661

# %%
password='O'
res=hashlib.md5(password.encode())
print(res.hexdigest())

password2='K'
res=hashlib.md5(password2.encode())
print(res.hexdigest())

password3='A'
res=hashlib.md5(password3.encode())
print(res.hexdigest())
# Out:
# f186217753c37b9b9f958d906208506e
# a5f3c6a11b03839d46af9fb43c97c188
# 7fc56270e7a70fa81a5935b72eacbe29

# %%
password1='Excuse'
res=hashlib.md5(password1.encode())
print(res.hexdigest())

password2='oka'
res2=hashlib.md5(password2.encode())
print(res2.hexdigest())

password3='OKA'
res3=hashlib.md5(password3.encode())
print(res3.hexdigest())
# Out:
# 202cb962ac59075b964b07152d234b70
# dcf80b2416ca823e8d807558a9310eb3
# 9531631c2f78b00a62583f0637fb3236

# %%
print(string.digits)
print(string.punctuation)
print(string.ascii_letters)
# Out:
# 0123456789
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# reerh
# reere
# reerr
# rerh
# rere
# rerr
# rerhh
# rerhe
# rerhr
# rereh
# reree
# rerer
# rerrh
# rerre
# rerrr
# rrh
# rre
# rrr
# rrhh
# rrhe
# rrhr
# rrhhh
# rrhhe
# rrhhr
# rrheh
# rrhee
# rrher
# rrhrh
# rrhre
# rrhrr
# rreh
# rree
# rrer
# rrehh
# rrehe
# rrehr
# rreeh
# rreee
# rreer
# rrerh
# rrere
# rrerr
# rrrh
# rrre
# rrrr
# rrrhh
# rrrhe
# rrrhr
# rrreh
# rrree
# rrrer
# rrrrh
# rrrre
# rrrrr

# %%
import time 
start = time.process_time() 
 
gen = generate('123', 2) 
for item in gen:     
    print(item) 
 
finish = time.process_time() 
print('Время работы в секундах: ', finish) 

import time 
start = time.process_time() 
 
gen = generate('OKA', 2) 
for item2 in gen:     
    print(item2) 
 
finish = time.process_time() 
print('Время работы в секундах: ', finish) 

import time 
start = time.process_time() 
 
gen = generate('oka', 2) 
for item3 in gen:     
    print(item3) 
 
finish = time.process_time() 
print('Время работы в секундах: ', finish)
# Out:
# 1
# 2
# 3
# Время работы в секундах:  3.796875
# O
# K
# A
# Время работы в секундах:  3.796875
# o
# k
# a
# Время работы в секундах:  3.796875

# %%
import hashlib
import string
import time
import itertools

# %%
password = 'Excuse'  
res = hashlib.md5(password.encode())  
print(res.hexdigest())

target_hash = "202cb962ac59075b964b07152d234b70"
alphabet = string.ascii_letters
start_time = time.time()

for combination in itertools.product(alphabet, repeat=5):
    password = ''.join(combination)  
    test_hash = hashlib.md5(password.encode()).hexdigest() 
    
    if test_hash == target_hash:
        print(f"Пароль найден: {password}")
        break

finish_time = time.time()
print(f"Время подбора: {finish_time - start_time:.6f} сек")
# Out:
# d82d3b800dbf931d6e13d3acde49e233
# Время подбора: 959.773903 сек

# %%
import hashlib
import string
import time
import itertools

# %%
password='albn'

# %%
res=hashlib.md5(password1.encode())

# %%
print(res.hexdigest())
# Out:
# 202cb962ac59075b964b07152d234b70

# %%
print(string.digits)
print(string.punctuation)
print(string.ascii_letters)
# Out:
# 0123456789
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
def generate(alphabet, max_len):     
    if max_len <= 0: return     
    for c in alphabet:         
        yield c     
    for c in alphabet:         
        for next in generate(alphabet, max_len-1):             
            yield c + next 

gen = generate('albn', 4) 

for item in gen:     
    print(item)
# Out:
# a
# l
# b
# n
# aa
# al
# ab
# an
# aaa
# aal
# aab
# aan
# aaaa
# aaal
# aaab
# aaan
# aala
# aall
# aalb
# aaln
# aaba
# aabl
# aabb
# aabn
# aana
# aanl
# aanb
# aann
# ala
# all
# alb
# aln
# alaa
# alal
# alab
# alan
# alla
# alll
# allb
# alln
# alba
# albl
# albb
# albn
# alna
# alnl
# alnb
# alnn
# aba
# abl
# abb
# abn
# abaa
# abal
# abab
# aban
# abla
# abll
# ablb
# abln
# abba
# abbl
# abbb
# abbn
# abna
# abnl
# abnb
# abnn
# ana
# anl
# anb
# ann
# anaa
# anal
# anab
# anan
# anla
# anll
# anlb
# anln
# anba
# anbl
# anbb
# anbn
# anna
# annl
# annb
# annn
# la
# ll
# lb
# ln
# laa
# lal
# lab
# lan
# laaa
# laal
# laab
# laan
# lala
# lall
# lalb
# laln
# laba
# labl
# labb
# labn
# lana
# lanl
# lanb
# lann
# lla
# lll
# llb
# lln
# llaa
# llal
# llab
# llan
# llla
# llll
# lllb
# llln
# llba
# llbl
# llbb
# llbn
# llna
# llnl
# llnb
# llnn
# lba
# lbl
# lbb
# lbn
# lbaa
# lbal
# lbab
# lban
# lbla
# lbll
# lblb
# lbln
# lbba
# lbbl
# lbbb
# lbbn
# lbna
# lbnl
# lbnb
# lbnn
# lna
# lnl
# lnb
# lnn
# lnaa
# lnal
# lnab
# lnan
# lnla
# lnll
# lnlb
# lnln
# lnba
# lnbl
# lnbb
# lnbn
# lnna
# lnnl
# lnnb
# lnnn
# ba
# bl
# bb
# bn
# baa
# bal
# bab
# ban
# baaa
# baal
# baab
# baan
# bala
# ball
# balb
# baln
# baba
# babl
# babb
# babn
# bana
# banl
# banb
# bann
# bla
# bll
# blb
# bln
# blaa
# blal
# blab
# blan
# blla
# blll
# bllb
# blln
# blba
# blbl
# blbb
# blbn
# blna
# blnl
# blnb
# blnn
# bba
# bbl
# bbb
# bbn
# bbaa
# bbal
# bbab
# bban
# bbla
# bbll
# bblb
# bbln
# bbba
# bbbl
# bbbb
# bbbn
# bbna
# bbnl
# bbnb
# bbnn
# bna
# bnl
# bnb
# bnn
# bnaa
# bnal
# bnab
# bnan
# bnla
# bnll
# bnlb
# bnln
# bnba
# bnbl
# bnbb
# bnbn
# bnna
# bnnl
# bnnb
# bnnn
# na
# nl
# nb
# nn
# naa
# nal
# nab
# nan
# naaa
# naal
# naab
# naan
# nala
# nall
# nalb
# naln
# naba
# nabl
# nabb
# nabn
# nana
# nanl
# nanb
# nann
# nla
# nll
# nlb
# nln
# nlaa
# nlal
# nlab
# nlan
# nlla
# nlll
# nllb
# nlln
# nlba
# nlbl
# nlbb
# nlbn
# nlna
# nlnl
# nlnb
# nlnn
# nba
# nbl
# nbb
# nbn
# nbaa
# nbal
# nbab
# nban
# nbla
# nbll
# nblb
# nbln
# nbba
# nbbl
# nbbb
# nbbn
# nbna
# nbnl
# nbnb
# nbnn
# nna
# nnl
# nnb
# nnn
# nnaa
# nnal
# nnab
# nnan
# nnla
# nnll
# nnlb
# nnln
# nnba
# nnbl
# nnbb
# nnbn
# nnna
# nnnl
# nnnb
# nnnn

# %%
password1='WatsApp'
res1=hashlib.md5(password1.encode())
print(res1.hexdigest())
# Out:
# 91a2be22d24236ed66ca446b1dd4f00d

# %%
target_hash = "91a2be22d24236ed66ca446b1dd4f00d"
alphabet = string.printable
start_time = time.time()

for combination in itertools.product(alphabet, repeat=5):
    password = ''.join(combination)  
    test_hash = hashlib.md5(password.encode()).hexdigest() 
    
    if test_hash == target_hash:
        print(f"Пароль найден: {password}")
        break

finish_time = time.time()
print(f"Время подбора: {finish_time - start_time:.6f} сек")
